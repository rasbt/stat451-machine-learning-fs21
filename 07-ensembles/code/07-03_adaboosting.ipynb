# %% [markdown]
# # STAT451: Machine Learning -- L07: Ensemble Methods Part 2/3

# %% [markdown]
# STAT 451: Intro to Machine Learning (Fall 2021)
# Instructor: Sebastian Raschka (sraschka@wisc.edu)

# %%
# %load_ext watermark
# %watermark -p scikit-learn,mlxtend
# Out:
# scikit-learn: 1.0
# mlxtend     : 0.19.0

# %% [markdown]
# # AdaBoost

# %%
from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn.ensemble import AdaBoostClassifier

data = datasets.load_breast_cancer()
X, y = data.data, data.target

X_temp, X_test, y_temp, y_test = \
    train_test_split(X, y, test_size=0.3, random_state=123, stratify=y)

X_train, X_valid, y_train, y_valid = \
    train_test_split(X_temp, y_temp, test_size=0.2, random_state=123, stratify=y_temp)

print('Train/Valid/Test sizes:', y_train.shape[0], y_valid.shape[0], y_test.shape[0])
# Out:
# Train/Valid/Test sizes: 318 80 171

# %%
tree = DecisionTreeClassifier(criterion='entropy',
                              random_state=1,
                              max_depth=1)


boost = AdaBoostClassifier(base_estimator=tree,
                           n_estimators=500,
                           algorithm='SAMME',
                           #n_jobs=1,
                           random_state=1)

boost.fit(X_train, y_train)
    
    
print("Valid Accuracy: %0.2f" % boost.score(X_valid, y_valid))
print("Test Accuracy: %0.2f" % boost.score(X_test, y_test))
# Out:
# Valid Accuracy: 0.97
# Test Accuracy: 0.98

# %%
boost.estimator_weights_
# Out:
# array([2.50552594, 1.92278773, 1.55587214, 1.25187013, 0.83252642,
#        1.08142915, 0.47669717, 0.52052104, 0.95125412, 0.80934036,
#        0.55109052, 1.05012036, 0.55221499, 0.63914069, 0.59736276,
#        0.73008531, 0.90592534, 0.70073463, 0.65650764, 0.61296891,
#        0.60313281, 0.25326461, 0.43373898, 0.78441489, 0.61236155,
#        1.0663583 , 0.90082217, 0.74116791, 0.56945746, 0.82543076,
#        0.7878422 , 0.64458085, 0.64797598, 0.87901285, 0.95523461,
#        0.76467063, 0.28370611, 0.76030775, 0.21207145, 0.68804838,
#        0.20617217, 0.3279255 , 0.62017215, 0.49812938, 0.51195149,
#        0.7236535 , 0.9534974 , 0.5063253 , 0.59993466, 0.33345466,
#        0.4770671 , 0.42432093, 0.32997923, 0.28444983, 0.66587665,
#        0.85117955, 0.52725978, 0.75103776, 0.57712158, 0.72617161,
#        0.68159588, 0.70714949, 0.61346881, 0.95838569, 0.49603377,
#        0.65835912, 0.41575424, 0.75348008, 0.60231214, 0.75623471,
#        0.878401  , 0.43486019, 0.74713028, 0.6171537 , 0.551583  ,
#        0.7560625 , 0.85264749, 0.43766225, 0.80434382, 0.67149846,
#        0.72092654, 1.00914516, 0.65784733, 0.72799295, 0.50237923,
#        0.60017745, 0.59266233, 0.70446006, 0.7924262 , 0.87568356,
#        0.77335321, 0.51540746, 0.65297512, 0.52861535, 0.56790548,
#        0.68888948, 0.74751924, 0.5212341 , 0.65688859, 0.5272307 ,
#        0.31189559, 0.7388376 , 0.41601534, 0.82160166, 0.83059175,
